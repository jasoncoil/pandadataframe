# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')
import numpy as np
import pickle

#Reading in LA Zoo attendance Data
df = pd.read_csv('L.A._Zoo_Attendance.csv')

#Setting the index to Fiscal Year, and then reversing the order so it goes from 2008-2012
df = df.set_index('Fiscal Year')
df = df.sort_values(['Fiscal Year'],ascending=True)

#Printing and Plotting the DataFrame 
print(df)
df.plot()
# Out:
#              Attendance
# Fiscal Year
# 2008-09         1556162
# 2009-10         1459080
# 2010-11         1543232
# 2011-12         1660450
# 2012-13         1506274
